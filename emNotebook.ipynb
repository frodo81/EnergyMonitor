# %%
# %run InsertAll.py
# Out:
# 2128-01-05 00:06:00 with (238.4,0.0,0.0) is already In DB!
# 2128-01-05 00:07:00 with (238.3,0.539,0.42) is already In DB!
# 2128-01-05 00:08:00 with (238.2,0.453,0.33) is already In DB!
# 2128-01-05 00:09:00 with (238.1,0.0,0.0) is already In DB!
# 2128-01-05 00:10:00 with (238.4,0.0,0.0) is already In DB!
# 2128-01-05 00:11:00 with (238.3,0.0,0.0) is already In DB!
# 2128-01-05 00:12:00 with (238.1,0.0,0.0) is already In DB!
# 2128-01-05 00:13:00 with (238.1,0.0,0.0) is already In DB!
# 2128-01-05 00:14:00 with (238.0,0.0,0.0) is already In DB!
# 2128-01-05 00:15:00 with (238.1,0.0,0.0) is already In DB!
# 2128-01-05 00:16:00 with (238.1,0.0,0.0) is already In DB!
# 2128-01-05 00:17:00 with (238.0,0.0,0.0) is already In DB!
# 2128-01-05 00:18:00 with (237.9,0.0,0.0) is already In DB!
# 2128-01-05 00:19:00 with (237.9,0.0,0.0) is already In DB!
# 2128-01-05 00:20:00 with (237.9,0.0,0.0) is already In DB!
# 2128-01-05 00:21:00 with (237.9,0.0,0.0) is already In DB!
# ...
